# %% [markdown]
# <a href="https://colab.research.google.com/github/pdfpythonhub/Build-a-PDF-Inspector/blob/main/How_to_Install_PyMuPDF_in_Google_Colab_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q -U pymupdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.7/25.7 MB 60.8 MB/s eta 0:00:00

# %%
import pymupdf
print(pymupdf.__version__)
# Out:
# 1.28.0
